# %% [markdown]
# # Importing

# %%
import pandas as pd 
import numpy as np
import geopandas as gpd
import fiona
import os
import zipfile
from folium import Map, CircleMarker, Vega, Popup, Marker, PolyLine, Icon, Choropleth, LayerControl
from folium.plugins import MarkerCluster, HeatMap, BeautifyIcon
import shapely
import matplotlib
from ipywidgets import interact
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.tsa 
from datetime import datetime
import missingno as msno

# %%
pd.set_option('display.max_rows', 100)

# %%
gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'
class Databases:
    def __init__(self, csv, anva, smm, metro):
        self.csv = csv
        self.anva = anva 
        self.smm = smm
        self.metro = metro

    def extract_csv(self):
        file = pd.read_csv(f'data/bike_loans/{self.csv}', sep=';')
        file['Fecha_Prestamo'] = pd.to_datetime(file['Fecha_Prestamo'])
        file['Fecha_Devolucion'] = pd.to_datetime(file['Fecha_Devolucion'])
        return file
        
    
    def extract_anva(self):
        bus_routes_AMVA = gpd.GeoDataFrame()
        for root, dirs, files in os.walk(f'data/bus_routes/medellin_bus_routes/{self.anva}'):
            for file in files:
                path = os.path.join(root, file)
                df = gpd.read_file(path, driver='KML')
                bus_routes_AMVA = gpd.GeoDataFrame(pd.concat([bus_routes_AMVA, df], ignore_index=True))
        return bus_routes_AMVA
    
    def extract_smm(self):
        smm_bus_routes = gpd.GeoDataFrame()
        for root, dirs, files in os.walk(f'data/bus_routes/medellin_bus_routes/{self.smm}'):
            for file in files:
                path = os.path.join(root, file)
                df = gpd.read_file(path, driver='KML')
                smm_bus_routes = gpd.GeoDataFrame(pd.concat([smm_bus_routes, df], ignore_index=True))
        return smm_bus_routes
    
    def extract_metro(self):
        metro_routes = gpd.GeoDataFrame()
        for root, dirs, files in os.walk(f'data/medellin_metro/{self.metro}'):
            for file in files:
                path = os.path.join(root, file)
                print(path)
                if path.endswith('.kmz'):
                    kmz = zipfile.ZipFile(path, 'r')
                    kml = kmz.open('doc.kml', 'r')
                    df = gpd.read_file(kml, driver='KML')
                    metro_routes = gpd.GeoDataFrame(pd.concat([metro_routes, df], ignore_index=True))
        return metro_routes

# %%
databases = Databases('bike_loans.csv','Kml Ruta AMVA','kml Ruta SMM','medellin_metro_stations')

# %%
bikes = databases.extract_csv()

# %%
bikes.dtypes
# Out:
# Id_Historico_Prestamo               int64
# Id_Usuario                          int64
# Id_Tag_Bicicleta                   object
# Fecha_Prestamo             datetime64[ns]
# Fecha_Devolucion           datetime64[ns]
# Id_Aparcamiento_Origen              int64
# Posicion_Origen                     int64
# Id_Aparcamiento_Destino           float64
# Posicion_Destino                  float64
# Importe                           float64
# DescripcionImporte                float64
# operario                           object
# Num_Bici_Hist                     float64
# dtype: object

# %% [markdown]
# ## Demand : Time Series

# %%
bikes['Fecha_Prestamo']
# Out:
# 0          2017-06-21 14:22:11
# 1          2017-06-21 14:07:18
# 2          2017-06-21 14:25:11
# 3          2017-06-21 13:35:52
# 4          2017-06-21 14:17:56
#                    ...
# 14225350   2021-04-20 18:46:57
# 14225351   2021-04-20 18:28:09
# 14225352   2021-04-20 18:59:53
# 14225353   2021-04-20 18:45:42
# 14225354   2021-04-20 18:39:06
# Name: Fecha_Prestamo, Length: 14225355, dtype: datetime64[ns]

# %% [markdown]
# In order to capture **trends and seasonality** properly, we decided to focus on **pre-pandemic** data. The first case diagnosed of Covid-19 in Colombia was on March 6th, 2020. Therefore, in order to avoid any bias in the data, we decided to focus on the data prior to 2020.

# %%
bikes_pre = bikes[bikes['Fecha_Prestamo'].dt.year < 2020]
bikes_pre
# Out:
#           Id_Historico_Prestamo  Id_Usuario Id_Tag_Bicicleta  \
# 0                       6501462       18701     000017B00743
# 1                       6501318       41811     000017AFF83C
# 2                       6501489       96620     000017AFFB6F
# 3                       6501001       16055     0000182A3B7B
# 4                       6501421        6431     000017AFE810
# ...                         ...         ...              ...
# 11767100               14454800       27944     0000F69A5A88
# 11767101               14454778      108800     00029A222B5E
# 11767102               14454793       98449     00001619CE0A
# 11767103               14454774      129665     000036885A88
# 11767179               14454588      121316     000026FE5A88
#
#               Fecha_Prestamo    Fecha_Devolucion  Id_Aparcamiento_Origen  \
# 0        2017-06-21 14:22:11 2017-06-21 14:38:29                       8
# 1        2017-06-21 14:07:18 2017-06-21 14:39:06                      56
# 2        2017-06-21 14:25:11 2017-06-21 14:39:07                      36
# 3        2017-06-21 13:35:52 2017-06-21 14:39:22                       8
# 4        2017-06-21 14:17:56 2017-06-21 14:39:26                      56
# ...                      ...                 ...                     ...
# 11767100 2019-12-31 13:58:55 2019-12-31 14:25:38                      40
# 11767101 2019-12-31 13:52:48 2019-12-31 14:40:52                      28
# 11767102 2019-12-31 13:55:47 2019-12-31 14:41:39                     113
# 11767103 2019-12-31 13:51:28 2019-12-31 16:27:12                      39
# 11767179 2019-12-31 13:15:55 2019-12-31 15:01:31                     103
#
#           Posicion_Origen  Id_Aparcamiento_Destino  Posicion_Destino  Importe  \
# 0                       1                     43.0               1.0      0.0
# 1                       6                     54.0               NaN      0.0
# 2                      25                      9.0              13.0      0.0
# 3                       1                      9.0               6.0      0.0
# 4                      14                     54.0               NaN      0.0
# ...                   ...                      ...               ...      ...
# 11767100                1                     50.0               1.0      0.0
# 11767101                1                     50.0               1.0      0.0
# 11767102                1                     28.0               1.0      0.0
# 11767103               15                     41.0              15.0      0.0
# 11767179                4                    118.0               4.0      0.0
#
#           DescripcionImporte         operario  Num_Bici_Hist
# 0                        NaN     jhon.castano          929.0
# 1                        NaN          monitor         1612.0
# 2                        NaN              NaN         1679.0
# 3                        NaN              NaN         1076.0
# 4                        NaN          monitor         1176.0
# ...                      ...              ...            ...
# 11767100                 NaN    claudia.marin          541.0
# 11767101                 NaN    claudia.marin          715.0
# 11767102                 NaN  edison.graciano         3497.0
# 11767103                 NaN              NaN          534.0
# 11767179                 NaN              NaN         2092.0
#
# [11766730 rows x 13 columns]

# %%
bikes_pre.shape
# Out:
# (11766730, 13)

# %%
#adding a new column to find the 
bikes_pre['loan_hour'] = bikes_pre['Fecha_Prestamo'].dt.hour
bikes_pre['loan_hour']
# Out:
# <ipython-input-11-b1beff32ffe2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bikes_pre['loan_hour'] = bikes_pre['Fecha_Prestamo'].dt.hour
# 0           14
# 1           14
# 2           14
# 3           13
# 4           14
#             ..
# 11767100    13
# 11767101    13
# 11767102    13
# 11767103    13
# 11767179    13
# Name: loan_hour, Length: 11766730, dtype: int64

# %%
bikes_pre['loan_hour'].value_counts()
# Out:
# 17    1228470
# 7      965999
# 16     920583
# 18     886511
# 12     864814
# 13     850919
# 11     797656
# 14     783512
# 15     774305
# 9      697068
# 6      674967
# 10     662295
# 8      654133
# 19     420379
# 20     287434
# 5      287063
# 21       5056
# 22       3689
# 4        1794
# 23         40
# 0          14
# 2          13
# 1           9
# 3           7
# Name: loan_hour, dtype: int64

# %%
# exploring the times of day where demand is strongest
plt.figure(figsize=(20,10))
plt.title('Distribution of Demand per Hour', size=20)
sns.boxplot(x=bikes_pre['loan_hour'])
# Out:
# <AxesSubplot:title={'center':'Distribution of Demand per Hour'}, xlabel='loan_hour'>

# %%
plt.figure(figsize=(20,10))
plt.title('Demand Per Hour', size=20)
sns.histplot(data=bikes_pre, x = 'loan_hour')
# Out:
# <AxesSubplot:title={'center':'Demand Per Hour'}, xlabel='loan_hour', ylabel='Count'>

# %%
# initializing new column Demand so that when we group by, we can see the amount of bikes demanded per hour
bikes_pre['demand'] = 1
# Out:
# <ipython-input-15-c71449922adb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bikes_pre['demand'] = 1

# %%
bikes_pre.head()
# Out:
#    Id_Historico_Prestamo  Id_Usuario Id_Tag_Bicicleta      Fecha_Prestamo  \
# 0                6501462       18701     000017B00743 2017-06-21 14:22:11
# 1                6501318       41811     000017AFF83C 2017-06-21 14:07:18
# 2                6501489       96620     000017AFFB6F 2017-06-21 14:25:11
# 3                6501001       16055     0000182A3B7B 2017-06-21 13:35:52
# 4                6501421        6431     000017AFE810 2017-06-21 14:17:56
#
#      Fecha_Devolucion  Id_Aparcamiento_Origen  Posicion_Origen  \
# 0 2017-06-21 14:38:29                       8                1
# 1 2017-06-21 14:39:06                      56                6
# 2 2017-06-21 14:39:07                      36               25
# 3 2017-06-21 14:39:22                       8                1
# 4 2017-06-21 14:39:26                      56               14
#
#    Id_Aparcamiento_Destino  Posicion_Destino  Importe  DescripcionImporte  \
# 0                     43.0               1.0      0.0                 NaN
# 1                     54.0               NaN      0.0                 NaN
# 2                      9.0              13.0      0.0                 NaN
# 3                      9.0               6.0      0.0                 NaN
# 4                     54.0               NaN      0.0                 NaN
#
#        operario  Num_Bici_Hist  loan_hour  demand
# 0  jhon.castano          929.0         14       1
# 1       monitor         1612.0         14       1
# 2           NaN         1679.0         14       1
# 3           NaN         1076.0         13       1
# 4       monitor         1176.0         14       1

# %%
bikes_pre['loan_date_hour'] = bikes_pre['Fecha_Prestamo'].dt.date.astype('string') + "-" + bikes_pre['loan_hour'].astype('string')
# Out:
# <ipython-input-55-a0a6fd1b69bf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bikes_pre['loan_date_hour'] = bikes_pre['Fecha_Prestamo'].dt.date.astype('string') + "-" + bikes_pre['loan_hour'].astype('string')

# %%
bikes_pre['loan_date_hour']
# Out:
# 0           2017-06-21-14
# 1           2017-06-21-14
# 2           2017-06-21-14
# 3           2017-06-21-13
# 4           2017-06-21-14
#                 ...
# 11767100    2019-12-31-13
# 11767101    2019-12-31-13
# 11767102    2019-12-31-13
# 11767103    2019-12-31-13
# 11767179    2019-12-31-13
# Name: loan_date_hour, Length: 11766730, dtype: string

# %%
bikes_pre.head()
# Out:
#    Id_Historico_Prestamo  Id_Usuario Id_Tag_Bicicleta      Fecha_Prestamo  \
# 0                6501462       18701     000017B00743 2017-06-21 14:22:11
# 1                6501318       41811     000017AFF83C 2017-06-21 14:07:18
# 2                6501489       96620     000017AFFB6F 2017-06-21 14:25:11
# 3                6501001       16055     0000182A3B7B 2017-06-21 13:35:52
# 4                6501421        6431     000017AFE810 2017-06-21 14:17:56
#
#      Fecha_Devolucion  Id_Aparcamiento_Origen  Posicion_Origen  \
# 0 2017-06-21 14:38:29                       8                1
# 1 2017-06-21 14:39:06                      56                6
# 2 2017-06-21 14:39:07                      36               25
# 3 2017-06-21 14:39:22                       8                1
# 4 2017-06-21 14:39:26                      56               14
#
#    Id_Aparcamiento_Destino  Posicion_Destino  Importe  DescripcionImporte  \
# 0                     43.0               1.0      0.0                 NaN
# 1                     54.0               NaN      0.0                 NaN
# 2                      9.0              13.0      0.0                 NaN
# 3                      9.0               6.0      0.0                 NaN
# 4                     54.0               NaN      0.0                 NaN
#
#        operario  Num_Bici_Hist  loan_hour  demand loan_date_hour  \
# 0  jhon.castano          929.0         14       1  2017-06-21-14
# 1       monitor         1612.0         14       1  2017-06-21-14
# 2           NaN         1679.0         14       1  2017-06-21-14
# 3           NaN         1076.0         13       1  2017-06-21-13
# 4       monitor         1176.0         14       1  2017-06-21-14
#
#   demand_per_station_per_time
# 0             1 2017-06-21 14
# 1             6 2017-06-21 14
# 2            25 2017-06-21 14
# 3             1 2017-06-21 13
# 4            14 2017-06-21 14

# %%
# 100 stations
demand_per_station = bikes_pre[['demand']].groupby(bikes_pre['Id_Aparcamiento_Origen']).sum()
demand_per_station.sort_values(by = 'demand', ascending=False)
# Out:
#                         demand
# Id_Aparcamiento_Origen
# 8                       660489
# 7                       565193
# 12                      420721
# 3                       409055
# 2                       361221
# 10                      347298
# 67                      334511
# 13                      331730
# 5                       323056
# 23                      321405
# 66                      313134
# 36                      297809
# 41                      297172
# 1                       284763
# 11                      257846
# 56                      256617
# 39                      254598
# 40                      243625
# 6                       242489
# 70                      231771
# 9                       225030
# 44                      217847
# 21                      212381
# 4                       190532
# 64                      190452
# 20                      188922
# 89                      185751
# 55                      184684
# 47                      182972
# 34                      177790
# 62                      171637
# 57                      167243
# 24                      154347
# 19                      153838
# 46                      152785
# 22                      148762
# 42                      147329
# 63                      134145
# 45                      121926
# 60                      121540
# 48                      119702
# 49                      108865
# 38                       99331
# 58                       96539
# 65                       96231
# 53                       94416
# 33                       93721
# 32                       89819
# 59                       80702
# 43                       72057
# 27                       71978
# 37                       63040
# 28                       61929
# 35                       53957
# 54                       51957
# 51                       45767
# 61                       44337
# 97                       42295
# 96                       36428
# 95                       23616
# 50                       18920
# 98                       15675
# 99                       12625
# 91                       11589
# 14                       11508
# 100                      10721
# 101                       8799
# 90                        8297
# 93                        7984
# 16                        7464
# 94                        7118
# 92                        3870
# 102                       3003
# 105                       1153
# 118                        851
# 113                        725
# 83                         696
# 115                        625
# 108                        587
# 69                         445
# 110                        419
# 111                        418
# 112                        392
# 109                        327
# 106                        288
# 114                        279
# 104                        270
# 25                         154
# 103                        149
# 31                          75
# 18                          59
# 15                          34
# 17                          29
# 71                          27
# 74                          26
# 26                           9
# 72                           7
# 75                           6
# 73                           2
# 52                           2

# %%
bikes_pre['demand_per_station_per_time'] = bikes_pre['Posicion_Origen'].astype('string') + " " + bikes_pre['loan_date_hour']
# Out:
# <ipython-input-59-14f6a97f0617>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bikes_pre['demand_per_station_per_time'] = bikes_pre['Posicion_Origen'].astype('string') + " " + bikes_pre['loan_date_hour']

# %%
bikes_pre
# Out:
#           Id_Historico_Prestamo  Id_Usuario Id_Tag_Bicicleta  \
# 0                       6501462       18701     000017B00743
# 1                       6501318       41811     000017AFF83C
# 2                       6501489       96620     000017AFFB6F
# 3                       6501001       16055     0000182A3B7B
# 4                       6501421        6431     000017AFE810
# ...                         ...         ...              ...
# 11767100               14454800       27944     0000F69A5A88
# 11767101               14454778      108800     00029A222B5E
# 11767102               14454793       98449     00001619CE0A
# 11767103               14454774      129665     000036885A88
# 11767179               14454588      121316     000026FE5A88
#
#               Fecha_Prestamo    Fecha_Devolucion  Id_Aparcamiento_Origen  \
# 0        2017-06-21 14:22:11 2017-06-21 14:38:29                       8
# 1        2017-06-21 14:07:18 2017-06-21 14:39:06                      56
# 2        2017-06-21 14:25:11 2017-06-21 14:39:07                      36
# 3        2017-06-21 13:35:52 2017-06-21 14:39:22                       8
# 4        2017-06-21 14:17:56 2017-06-21 14:39:26                      56
# ...                      ...                 ...                     ...
# 11767100 2019-12-31 13:58:55 2019-12-31 14:25:38                      40
# 11767101 2019-12-31 13:52:48 2019-12-31 14:40:52                      28
# 11767102 2019-12-31 13:55:47 2019-12-31 14:41:39                     113
# 11767103 2019-12-31 13:51:28 2019-12-31 16:27:12                      39
# 11767179 2019-12-31 13:15:55 2019-12-31 15:01:31                     103
#
#           Posicion_Origen  Id_Aparcamiento_Destino  Posicion_Destino  Importe  \
# 0                       1                     43.0               1.0      0.0
# 1                       6                     54.0               NaN      0.0
# 2                      25                      9.0              13.0      0.0
# 3                       1                      9.0               6.0      0.0
# 4                      14                     54.0               NaN      0.0
# ...                   ...                      ...               ...      ...
# 11767100                1                     50.0               1.0      0.0
# 11767101                1                     50.0               1.0      0.0
# 11767102                1                     28.0               1.0      0.0
# 11767103               15                     41.0              15.0      0.0
# 11767179                4                    118.0               4.0      0.0
#
#           DescripcionImporte         operario  Num_Bici_Hist  loan_hour  \
# 0                        NaN     jhon.castano          929.0         14
# 1                        NaN          monitor         1612.0         14
# 2                        NaN              NaN         1679.0         14
# 3                        NaN              NaN         1076.0         13
# 4                        NaN          monitor         1176.0         14
# ...                      ...              ...            ...        ...
# 11767100                 NaN    claudia.marin          541.0         13
# 11767101                 NaN    claudia.marin          715.0         13
# 11767102                 NaN  edison.graciano         3497.0         13
# 11767103                 NaN              NaN          534.0         13
# 11767179                 NaN              NaN         2092.0         13
#
#           demand loan_date_hour demand_per_station_per_time
# 0              1  2017-06-21-14             1 2017-06-21-14
# 1              1  2017-06-21-14             6 2017-06-21-14
# 2              1  2017-06-21-14            25 2017-06-21-14
# 3              1  2017-06-21-13             1 2017-06-21-13
# 4              1  2017-06-21-14            14 2017-06-21-14
# ...          ...            ...                         ...
# 11767100       1  2019-12-31-13             1 2019-12-31-13
# 11767101       1  2019-12-31-13             1 2019-12-31-13
# 11767102       1  2019-12-31-13             1 2019-12-31-13
# 11767103       1  2019-12-31-13            15 2019-12-31-13
# 11767179       1  2019-12-31-13             4 2019-12-31-13
#
# [11766730 rows x 17 columns]

# %%
demand_per_station_per_time = bikes_pre[['demand']].groupby(bikes_pre['demand_per_station_per_time']).sum()

# %%
demand_per_station_per_time.reset_index(inplace=True)

# %%
demand_per_station_per_time
# Out:
#        demand_per_station_per_time  demand
# 0                  1 2014-05-30-15       1
# 1                  1 2014-05-30-17       2
# 2                  1 2014-05-30-22       2
# 3                  1 2014-06-01-20       6
# 4                  1 2014-06-02-11       1
# ...                            ...     ...
# 615783              9 2019-12-31-5       2
# 615784              9 2019-12-31-6       2
# 615785              9 2019-12-31-7       4
# 615786              9 2019-12-31-8       7
# 615787              9 2019-12-31-9       9
#
# [615788 rows x 2 columns]

# %%
demand_per_station_per_time[['station','date-time']] = demand_per_station_per_time.demand_per_station_per_time.str.split(" ",expand=True,)

# %%
# demand_per_station_per_time['station']= demand_per_station_per_time['date-time'].day

# %%
# as we can see the greatest demand is for station 1 between 17-18
demand_per_station_per_time.sort_values(by = 'demand', ascending =False).head(100)
# Out:
#       demand_per_station_per_time  demand station      date-time
# 22922             1 2019-08-21-17    1511       1  2019-08-21-17
# 23753             1 2019-10-15-17    1499       1  2019-10-15-17
# 23338             1 2019-09-17-17    1470       1  2019-09-17-17
# 23375             1 2019-09-19-17    1464       1  2019-09-19-17
# 22829             1 2019-08-14-17    1458       1  2019-08-14-17
# 22903             1 2019-08-20-17    1457       1  2019-08-20-17
# 22810             1 2019-08-13-17    1457       1  2019-08-13-17
# 23319             1 2019-09-16-17    1457       1  2019-09-16-17
# 23644             1 2019-10-07-17    1452       1  2019-10-07-17
# 23014             1 2019-08-27-17    1447       1  2019-08-27-17
# 24085             1 2019-11-06-17    1444       1  2019-11-06-17
# 23482             1 2019-09-26-17    1431       1  2019-09-26-17
# 22940             1 2019-08-22-17    1431       1  2019-08-22-17
# 22791             1 2019-08-12-17    1425       1  2019-08-12-17
# 23572             1 2019-10-02-17    1418       1  2019-10-02-17
# 23105             1 2019-09-02-17    1410       1  2019-09-02-17
# 23032             1 2019-08-28-17    1406       1  2019-08-28-17
# 20696             1 2019-03-19-17    1398       1  2019-03-19-17
# 22995             1 2019-08-26-17    1397       1  2019-08-26-17
# 22848             1 2019-08-15-17    1388       1  2019-08-15-17
# 23141             1 2019-09-04-17    1382       1  2019-09-04-17
# 23590             1 2019-10-03-17    1382       1  2019-10-03-17
# 23051             1 2019-08-29-17    1381       1  2019-08-29-17
# 23230             1 2019-09-10-17    1377       1  2019-09-10-17
# 23662             1 2019-10-08-17    1368       1  2019-10-08-17
# 22699             1 2019-08-05-17    1364       1  2019-08-05-17
# 23862             1 2019-10-22-17    1362       1  2019-10-22-17
# 23123             1 2019-09-03-17    1361       1  2019-09-03-17
# 23954             1 2019-10-28-17    1360       1  2019-10-28-17
# 22736             1 2019-08-08-17    1356       1  2019-08-08-17
# 20482             1 2019-03-05-17    1353       1  2019-03-05-17
# 22537             1 2019-07-25-17    1353       1  2019-07-25-17
# 23843             1 2019-10-21-17    1345       1  2019-10-21-17
# 20804             1 2019-03-27-17    1345       1  2019-03-27-17
# 23248             1 2019-09-11-17    1345       1  2019-09-11-17
# 23973             1 2019-10-29-17    1339       1  2019-10-29-17
# 21900             1 2019-06-11-17    1339       1  2019-06-11-17
# 23159             1 2019-09-05-17    1336       1  2019-09-05-17
# 20519             1 2019-03-07-17    1335       1  2019-03-07-17
# 23900             1 2019-10-24-17    1333       1  2019-10-24-17
# 24066             1 2019-11-05-17    1327       1  2019-11-05-17
# 20625             1 2019-03-14-17    1322       1  2019-03-14-17
# 20607             1 2019-03-13-17    1318       1  2019-03-13-17
# 21599             1 2019-05-21-17    1310       1  2019-05-21-17
# 23681             1 2019-10-09-17    1309       1  2019-10-09-17
# 23212             1 2019-09-09-17    1308       1  2019-09-09-17
# 20678             1 2019-03-18-17    1305       1  2019-03-18-17
# 23266             1 2019-09-12-17    1303       1  2019-09-12-17
# 22501             1 2019-07-23-17    1303       1  2019-07-23-17
# 23992             1 2019-10-30-17    1298       1  2019-10-30-17
# 22717             1 2019-08-06-17    1297       1  2019-08-06-17
# 23771             1 2019-10-16-17    1290       1  2019-10-16-17
# 22959             1 2019-08-23-17    1285       1  2019-08-23-17
# 22519             1 2019-07-24-17    1277       1  2019-07-24-17
# 21488             1 2019-05-14-17    1274       1  2019-05-14-17
# 21742             1 2019-05-30-17    1274       1  2019-05-30-17
# 21794             1 2019-06-04-17    1273       1  2019-06-04-17
# 21688             1 2019-05-27-17    1271       1  2019-05-27-17
# 20501             1 2019-03-06-17    1268       1  2019-03-06-17
# 20896             1 2019-04-02-17    1267       1  2019-04-02-17
# 22645             1 2019-08-01-17    1267       1  2019-08-01-17
# 22007             1 2019-06-18-17    1265       1  2019-06-18-17
# 21989             1 2019-06-17-17    1256       1  2019-06-17-17
# 22609             1 2019-07-30-17    1254       1  2019-07-30-17
# 23609             1 2019-10-04-17    1253       1  2019-10-04-17
# 22591             1 2019-07-29-17    1251       1  2019-07-29-17
# 21581             1 2019-05-20-17    1248       1  2019-05-20-17
# 22627             1 2019-07-31-17    1247       1  2019-07-31-17
# 20914             1 2019-04-03-17    1245       1  2019-04-03-17
# 22755             1 2019-08-09-17    1242       1  2019-08-09-17
# 20046             1 2019-02-04-17    1240       1  2019-02-04-17
# 23500             1 2019-09-27-17    1237       1  2019-09-27-17
# 23807             1 2019-10-18-17    1237       1  2019-10-18-17
# 21377             1 2019-05-07-17    1225       1  2019-05-07-17
# 20358             1 2019-02-25-17    1223       1  2019-02-25-17
# 20932             1 2019-04-04-17    1222       1  2019-04-04-17
# 24249             1 2019-11-18-17    1214       1  2019-11-18-17
# 23700             1 2019-10-10-17    1214       1  2019-10-10-17
# 24104             1 2019-11-07-17    1213       1  2019-11-07-17
# 21507             1 2019-05-15-17    1209       1  2019-05-15-17
# 22043             1 2019-06-20-17    1208       1  2019-06-20-17
# 20842             1 2019-03-29-17    1207       1  2019-03-29-17
# 22483             1 2019-07-22-17    1206       1  2019-07-22-17
# 21918             1 2019-06-12-17    1203       1  2019-06-12-17
# 23554             1 2019-10-01-17    1202       1  2019-10-01-17
# 22116             1 2019-06-26-17    1196       1  2019-06-26-17
# 24376             1 2019-11-26-17    1196       1  2019-11-26-17
# 21882             1 2019-06-10-17    1195       1  2019-06-10-17
# 23070             1 2019-08-30-17    1195       1  2019-08-30-17
# 23718             1 2019-10-11-17    1192       1  2019-10-11-17
# 21396             1 2019-05-08-17    1186       1  2019-05-08-17
# 23284             1 2019-09-13-17    1185       1  2019-09-13-17
# 23177             1 2019-09-06-17    1181       1  2019-09-06-17
# 24011             1 2019-10-31-17    1179       1  2019-10-31-17
# 20065             1 2019-02-05-17    1179       1  2019-02-05-17
# 22389             1 2019-07-15-17    1175       1  2019-07-15-17
# 21812             1 2019-06-05-17    1175       1  2019-06-05-17
# 20785             1 2019-03-26-17    1172       1  2019-03-26-17
# 24357             1 2019-11-25-17    1172       1  2019-11-25-17
# 21020             1 2019-04-10-17    1171       1  2019-04-10-17

# %%
df = demand_per_station_per_time.copy()
df
# Out:
#        demand_per_station_per_time  demand station      date-time
# 0                  1 2014-05-30-15       1       1  2014-05-30-15
# 1                  1 2014-05-30-17       2       1  2014-05-30-17
# 2                  1 2014-05-30-22       2       1  2014-05-30-22
# 3                  1 2014-06-01-20       6       1  2014-06-01-20
# 4                  1 2014-06-02-11       1       1  2014-06-02-11
# ...                            ...     ...     ...            ...
# 615783              9 2019-12-31-5       2       9   2019-12-31-5
# 615784              9 2019-12-31-6       2       9   2019-12-31-6
# 615785              9 2019-12-31-7       4       9   2019-12-31-7
# 615786              9 2019-12-31-8       7       9   2019-12-31-8
# 615787              9 2019-12-31-9       9       9   2019-12-31-9
#
# [615788 rows x 4 columns]

# %%
df[df['station'] == '1']
# as you can see we have gaps in the time series, however, I am reading about imputing new rows to fill those.
# In 2014, there will be a lot more gaps than in 2019, since the project was developed.
# Out:
#       demand_per_station_per_time  demand station      date-time
# 0                 1 2014-05-30-15       1       1  2014-05-30-15
# 1                 1 2014-05-30-17       2       1  2014-05-30-17
# 2                 1 2014-05-30-22       2       1  2014-05-30-22
# 3                 1 2014-06-01-20       6       1  2014-06-01-20
# 4                 1 2014-06-02-11       1       1  2014-06-02-11
# ...                           ...     ...     ...            ...
# 24884              1 2019-12-31-5      80       1   2019-12-31-5
# 24885              1 2019-12-31-6     167       1   2019-12-31-6
# 24886              1 2019-12-31-7     200       1   2019-12-31-7
# 24887              1 2019-12-31-8     156       1   2019-12-31-8
# 24888              1 2019-12-31-9     199       1   2019-12-31-9
#
# [24889 rows x 4 columns]

# %%
msno.matrix(df,figsize=(12,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Since it will be difficult to built a time-series with all the stations, maybe we can build a function where you impute
# which station you would like to forecast the demand for, and it tells you.

# %% [markdown]
# What I was also thinking is to have the same df as above, but add new columns with like number of times it reached this destination IDs.
# So for example, have another 100 columns (each representing a station of **destination demand**.
#
# The last row has 199 demand, but how do we know where they are goin ?

# %% [markdown]
# Other interesting columns we can add are **seasons, holidays, working, days, temp, windy speed**
#
# https://www.kaggle.com/viveksrinivasan/eda-ensemble-model-top-10-percentile

# %%
df.dtypes
# Out:
# demand_per_station_per_time    object
# demand                          int64
# station                        object
# date-time                      object
# dtype: object

# %%
def stime(x):
    x['time'] = x['date-time'].split('-')[-1]
    x['date']= '-'.join(x['date-time'].split('-')[:-1])
    return x

# %%
df = df.apply(stime, axis=1)

# %%
df
# Out:
#        demand_per_station_per_time  demand station      date-time time  \
# 0                  1 2014-05-30-15       1       1  2014-05-30-15   15
# 1                  1 2014-05-30-17       2       1  2014-05-30-17   17
# 2                  1 2014-05-30-22       2       1  2014-05-30-22   22
# 3                  1 2014-06-01-20       6       1  2014-06-01-20   20
# 4                  1 2014-06-02-11       1       1  2014-06-02-11   11
# ...                            ...     ...     ...            ...  ...
# 615783              9 2019-12-31-5       2       9   2019-12-31-5    5
# 615784              9 2019-12-31-6       2       9   2019-12-31-6    6
# 615785              9 2019-12-31-7       4       9   2019-12-31-7    7
# 615786              9 2019-12-31-8       7       9   2019-12-31-8    8
# 615787              9 2019-12-31-9       9       9   2019-12-31-9    9
#
#               date
# 0       2014-05-30
# 1       2014-05-30
# 2       2014-05-30
# 3       2014-06-01
# 4       2014-06-02
# ...            ...
# 615783  2019-12-31
# 615784  2019-12-31
# 615785  2019-12-31
# 615786  2019-12-31
# 615787  2019-12-31
#
# [615788 rows x 6 columns]

# %%
# aggregated demand per hour between 2014-2019 
ad_per_hour = df.groupby('time').sum()
ad_per_hour.sort_index(ascending=True)
# Out:
#        demand
# time
# 0          14
# 1           9
# 10     662295
# 11     797656
# 12     864814
# 13     850919
# 14     783512
# 15     774305
# 16     920583
# 17    1228470
# 18     886511
# 19     420379
# 2          13
# 20     287434
# 21       5056
# 22       3689
# 23         40
# 3           7
# 4        1794
# 5      287063
# 6      674967
# 7      965999
# 8      654133
# 9      697068

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=ad_per_hour, x=ad_per_hour.index, y='demand')
# Out:
# <AxesSubplot:xlabel='time', ylabel='demand'>

# %% [markdown]
# let's keep the last 30% values out for test purposes
# Contiguous (train ➔ test) split mandator
#
# train_size = 0.7
#
# index = round(train_size*df.shape[0])
#
# df_train = df.iloc[:index]
#
# df_test = df.iloc[index+1:]

# %%
def convert_to_date(x):
    return datetime.strptime(x, '%Y-%m-%d-%H')

# %%
df['year_month_day_hour'] = df['date-time']
df = df.drop(columns='date-time')

# %%
# df.drop(columns='demand_per_station_per_time', inplace=True)

# %%
df['year_month_day_hour']= pd.to_datetime(df['year_month_day_hour'], infer_datetime_format=True)

# %%
df.dtypes
# Out:
# demand                          int64
# station                        object
# time                           object
# date                           object
# year_month_day_hour    datetime64[ns]
# dtype: object

# %%
df
# Out:
#         demand station time        date year_month_day_hour
# 0            1       1   15  2014-05-30 2014-05-30 15:00:00
# 1            2       1   17  2014-05-30 2014-05-30 17:00:00
# 2            2       1   22  2014-05-30 2014-05-30 22:00:00
# 3            6       1   20  2014-06-01 2014-06-01 20:00:00
# 4            1       1   11  2014-06-02 2014-06-02 11:00:00
# ...        ...     ...  ...         ...                 ...
# 615783       2       9    5  2019-12-31 2019-12-31 05:00:00
# 615784       2       9    6  2019-12-31 2019-12-31 06:00:00
# 615785       4       9    7  2019-12-31 2019-12-31 07:00:00
# 615786       7       9    8  2019-12-31 2019-12-31 08:00:00
# 615787       9       9    9  2019-12-31 2019-12-31 09:00:00
#
# [615788 rows x 5 columns]
