# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import folium 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
raw_data = gpd.read_file('wdl_data/m_risk_prfile.shp')

# %%
raw_data
# Out:
#           Link_ID      linkid   Daily_Aver  Average_Ve  Median_of_  \
# 0        80216819    80216819  6224.778569   45.208716   44.464286
# 1        80216858    80216858  2236.054168   79.563308   82.750000
# 2        80216859    80216859  2138.725039   65.955069   67.333333
# 3        80216860    80216860  2201.335041   47.533911   44.000000
# 4        80216867    80216867  2102.610278   51.375291   53.250000
# ...           ...         ...          ...         ...         ...
# 34673  1223266734  1223266734  2301.997364   44.392857   43.500000
# 34674  1223277122  1223277122  1655.507135  106.848684  109.500000
# 34675  1223277123  1223277123  1665.608140  108.863821  114.250000
# 34676  1223277124  1223277124  2580.645483  104.774517  108.375000
# 34677  1223277125  1223277125  1592.981953  108.784483  111.500000
#
#        First_Quar  Third_Quar  Func_Class  Speed_Cat  \
# 0       28.000000       59.00           2          6
# ...

# %%
m = folium.Map(location=[38.72, -9.14], width=750, height=500)

# %%
raw_data.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_db456_row0_col0,#T_db456_row0_col1,#T_db456_row1_col0,#T_db456_row1_col1,#T_db456_row2_col2,#T_db456_row3_col3,#T_db456_row4_col4,#T_db456_row5_col5,#T_db456_row6_col6,#T_db456_row7_col7,#T_db456_row8_col8{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_db456_row0_col2,#T_db456_row1_col2{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_db456_row0_col3,#T_db456_row1_col3{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_db456_row0_col4,#T_db456_row1_col4{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }#T_db456_row0_col5,#T_db456_row1_col5,#T_db456_row2_col4{
#             background-color:  #cedaeb;
#             color:  #000000;
#         }#T_db456_row0_col6,#T_db456_row1_col6,#T_db456_row2_col5{
#             background-color:  #c9d7f0;
#             color:  #000000;
# ...

# %%
raw_data.columns
# Out:
# Index(['Link_ID', 'linkid', 'Daily_Aver', 'Average_Ve', 'Median_of_',
#        'First_Quar', 'Third_Quar', 'Func_Class', 'Speed_Cat', 'geometry'],
#       dtype='object')

# %%
sns.histplot(raw_data,x='Median_of_',y='First_Quar')
# plt.xlim(200)
plt.ylim(0,200)
# Out:
# (0.0, 200.0)
