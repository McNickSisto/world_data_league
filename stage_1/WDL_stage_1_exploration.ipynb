# %%
import pandas as pd

# %% [markdown]
# ## Import data

# %%
data_senior = pd.read_csv('raw_data/senior_transportation.csv')
data_bus = pd.read_csv('raw_data/bus_routes.csv')
data_users = pd.read_csv('raw_data/churn_users.csv')
data_od = pd.read_csv('raw_data/churn_OD.csv')

# %%
data_bus
# Out:
#        IDRoute      linkid
# 0            1   537277300
# 1            1   537277673
# 2            1   537277754
# 3            1   537277777
# 4            1   537277795
# ...        ...         ...
# 48307      166  1226896489
# 48308      166  1226896507
# 48309      166  1226896508
# 48310      166  1226896568
# 48311      166  1226896569
#
# [48312 rows x 2 columns]

# %%
data_od
# Out:
#      Region_of_Origin District_of_Origin   County_of_Origin  \
# 0      R1 - AM Lisboa             Lisboa            Amadora
# 1      R1 - AM Lisboa             Lisboa            Amadora
# 2      R1 - AM Lisboa             Lisboa            Amadora
# 3      R1 - AM Lisboa             Lisboa            Amadora
# 4      R1 - AM Lisboa             Lisboa            Amadora
# ...               ...                ...                ...
# 2248    R2 - AM Porto              Porto  Vila Nova de Gaia
# 2249    R2 - AM Porto              Porto  Vila Nova de Gaia
# 2250    R2 - AM Porto              Porto  Vila Nova de Gaia
# 2251    R2 - AM Porto              Porto  Vila Nova de Gaia
# 2252    R2 - AM Porto              Porto  Vila Nova de Gaia
#
#      Region_of_Public_Transportation District_of_Public_Transportation  \
# 0                     R1 - AM Lisboa                            LISBOA
# 1                     R1 - AM Lisboa                            LISBOA
# ...

# %%
data_users
# Out:
#     Region_of_Origin District_of_Origin   County_of_Origin            Period  \
# 0     R1 - AM Lisboa             Lisboa            Amadora  Sep-19 to Feb-20
# 1     R1 - AM Lisboa             Lisboa            Amadora  Sep-19 to Feb-20
# 2     R1 - AM Lisboa             Lisboa            Amadora  Sep-19 to Feb-20
# 3     R1 - AM Lisboa             Lisboa            Amadora  Sep-19 to Feb-20
# 4     R1 - AM Lisboa             Lisboa            Amadora  Sep-19 to Feb-20
# ..               ...                ...                ...               ...
# 539    R2 - AM Porto              Porto  Vila Nova de Gaia  Sep-20 to Jan-21
# 540    R2 - AM Porto              Porto  Vila Nova de Gaia  Sep-20 to Jan-21
# 541    R2 - AM Porto              Porto  Vila Nova de Gaia  Sep-20 to Jan-21
# 542    R2 - AM Porto              Porto  Vila Nova de Gaia  Sep-20 to Jan-21
# 543    R2 - AM Porto              Porto  Vila Nova de Gaia  Sep-20 to Jan-21
#
# ...

# %% [markdown]
# ## API

# %%
import requests

username = 'nicosisto@hotmail.com'
pwd = '2C81D9D8-8F01-4EBA-9BE4-FCB9FAC13166'
url = "www.transporlis.pt/Webservice_dadosabertos/DadosAbertos.svc"

response = requests.get(url).json()

print(response)
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-54-564d15601b7a> in <module>
#       5 url = "www.transporlis.pt/Webservice_dadosabertos/DadosAbertos.svc"
#       6
# ----> 7 response = requests.get(url).json()
#       8
#       9 print(response)
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ...
